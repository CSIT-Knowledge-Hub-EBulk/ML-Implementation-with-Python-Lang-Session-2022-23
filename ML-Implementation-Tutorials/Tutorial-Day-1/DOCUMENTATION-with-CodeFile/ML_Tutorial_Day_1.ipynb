# %%
#import numpy as np
import pandas as pd

# %% [markdown]
# # Loading a .csv file into a pandas DataFrame

# %%
pd.read_csv('zoo.csv', delimiter = ',')
# Out:
#       animal  uniq_id  water_need
# 0   elephant     1001         500
# 1   elephant     1002         600
# 2   elephant     1003         550
# 3      tiger     1004         300
# 4      tiger     1005         320
# 5      tiger     1006         330
# 6      tiger     1007         290
# 7      tiger     1008         310
# 8      zebra     1009         200
# 9      zebra     1010         220
# 10     zebra     1011         240
# 11     zebra     1012         230
# 12     zebra     1013         220
# 13     zebra     1014         100
# 14     zebra     1015          80
# 15      lion     1016         420
# 16      lion     1017         600
# 17      lion     1018         500
# 18      lion     1019         390
# 19  kangaroo     1020         410
# 20  kangaroo     1021         430
# 21  kangaroo     1022         410

# %%
pd.read_csv('Iris.csv',delimiter = ',')
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
#Id	SepalLengthCm	SepalWidthCm	PetalLengthCm	PetalWidthCm	Species
#['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm', 'Species']

# %%
pd.read_csv('Iris _C.csv',delimiter = ',')
# Out:
#        1  5.1  3.5  1.4  0.2     Iris-setosa
# 0      2  4.9  3.0  1.4  0.2     Iris-setosa
# 1      3  4.7  3.2  1.3  0.2     Iris-setosa
# 2      4  4.6  3.1  1.5  0.2     Iris-setosa
# 3      5  5.0  3.6  1.4  0.2     Iris-setosa
# 4      6  5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...  ...             ...
# 144  146  6.7  3.0  5.2  2.3  Iris-virginica
# 145  147  6.3  2.5  5.0  1.9  Iris-virginica
# 146  148  6.5  3.0  5.2  2.0  Iris-virginica
# 147  149  6.2  3.4  5.4  2.3  Iris-virginica
# 148  150  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 6 columns]

# %%
pd.read_csv('Iris _C.csv', delimiter = ',', names = ['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm', 'Species'])
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# # Selecting data from a DataFrame in pandas

# %% [markdown]
# 1. How to print the whole DataFrame

# %%
DF_C=pd.read_csv('Iris _C.csv', names = ['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm', 'Species'])

# %%
DF_C
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# #2 How to print a sample of your dataframe
# 2.1 (e.g. first 5 rows)

# %%
DF_C.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
DF_C. loc[[2]]
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa

# %% [markdown]
# #2 How to print a sample of your dataframe
# 2.2 (e.g. last 5 rows)

# %%
DF_C.tail(5)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %% [markdown]
# #2 How to print a sample of your dataframe
# 2.3 (e.g. random)

# %%
DF_C.sample(5)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 66    67            5.6           3.0            4.5           1.5
# 120  121            6.9           3.2            5.7           2.3
# 104  105            6.5           3.0            5.8           2.2
# 28    29            5.2           3.4            1.4           0.2
# 78    79            6.0           2.9            4.5           1.5
#
#              Species
# 66   Iris-versicolor
# 120   Iris-virginica
# 104   Iris-virginica
# 28       Iris-setosa
# 78   Iris-versicolor

# %% [markdown]
# # 3 How to select specific columns of your DataFrame

# %%
DF_C[['Id', 'Species']]
# Out:
#       Id         Species
# 0      1     Iris-setosa
# 1      2     Iris-setosa
# 2      3     Iris-setosa
# 3      4     Iris-setosa
# 4      5     Iris-setosa
# ..   ...             ...
# 145  146  Iris-virginica
# 146  147  Iris-virginica
# 147  148  Iris-virginica
# 148  149  Iris-virginica
# 149  150  Iris-virginica
#
# [150 rows x 2 columns]

# %% [markdown]
# change the order of the column names, the order of the returned columns will change, too:

# %%
DF_C[['Species','Id']]
# Out:
#             Species   Id
# 0       Iris-setosa    1
# 1       Iris-setosa    2
# 2       Iris-setosa    3
# 3       Iris-setosa    4
# 4       Iris-setosa    5
# ..              ...  ...
# 145  Iris-virginica  146
# 146  Iris-virginica  147
# 147  Iris-virginica  148
# 148  Iris-virginica  149
# 149  Iris-virginica  150
#
# [150 rows x 2 columns]

# %% [markdown]
# Series objects instead of DataFrames

# %%
DF_C.Species
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Species, Length: 150, dtype: object

# %%
DF_C['Species']
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Species, Length: 150, dtype: object

# %% [markdown]
# # 4 How to filter for specific values in your DataFrame
