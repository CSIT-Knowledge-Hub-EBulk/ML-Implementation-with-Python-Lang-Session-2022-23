# %% [markdown]
# **Connect to drive**

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# **Import library**

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('/content/gdrive/MyDrive/DA_2023_lab/SMSSpamCollection.txt',sep='\t')

# %%
data
# Out:
#        ham  \
# 0      ham
# 1     spam
# 2      ham
# 3      ham
# 4     spam
# ...    ...
# 5566  spam
# 5567   ham
# 5568   ham
# 5569   ham
# 5570   ham
#
#      Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...
# 0                         Ok lar... Joking wif u oni...
# 1     Free entry in 2 a wkly comp to win FA Cup fina...
# 2     U dun say so early hor... U c already then say...
# 3     Nah I don't think he goes to usf, he lives aro...
# 4     FreeMsg Hey there darling it's been 3 week's n...
# ...                                                 ...
# 5566  This is the 2nd time we have tried 2 contact u...
# 5567               Will ü b going to esplanade fr home?
# 5568  Pity, * was in mood for that. So...any other s...
# 5569  The guy did some bitching but I acted like i'd...
# 5570                         Rofl. Its true to its name
#
# [5571 rows x 2 columns]

# %%
data.head(20)
# Out:
#      ham  \
# 0    ham
# 1   spam
# 2    ham
# 3    ham
# 4   spam
# 5    ham
# 6    ham
# 7   spam
# 8   spam
# 9    ham
# 10  spam
# 11  spam
# 12   ham
# 13   ham
# 14  spam
# 15   ham
# 16   ham
# 17   ham
# 18  spam
# 19   ham
#
#    Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...
# 0                       Ok lar... Joking wif u oni...
# 1   Free entry in 2 a wkly comp to win FA Cup fina...
# 2   U dun say so early hor... U c already then say...
# 3   Nah I don't think he goes to usf, he lives aro...
# 4   FreeMsg Hey there darling it's been 3 week's n...
# 5   Even my brother is not like to speak with me. ...
# 6   As per your request 'Melle Melle (Oru Minnamin...
# 7   WINNER!! As a valued network customer you have...
# 8   Had your mobile 11 months or more? U R entitle...
# 9   I'm gonna be home soon and i don't want to tal...
# 10  SIX chances to win CASH! From 100 to 20,000 po...
# ...

# %%
data.tail()
# Out:
#        ham  \
# 5566  spam
# 5567   ham
# 5568   ham
# 5569   ham
# 5570   ham
#
#      Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...
# 5566  This is the 2nd time we have tried 2 contact u...
# 5567               Will ü b going to esplanade fr home?
# 5568  Pity, * was in mood for that. So...any other s...
# 5569  The guy did some bitching but I acted like i'd...
# 5570                         Rofl. Its true to its name

# %%
data.iloc[2:8]
# Out:
#     ham  \
# 2   ham
# 3   ham
# 4  spam
# 5   ham
# 6   ham
# 7  spam
#
#   Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...
# 2  U dun say so early hor... U c already then say...
# 3  Nah I don't think he goes to usf, he lives aro...
# 4  FreeMsg Hey there darling it's been 3 week's n...
# 5  Even my brother is not like to speak with me. ...
# 6  As per your request 'Melle Melle (Oru Minnamin...
# 7  WINNER!! As a valued network customer you have...

# %% [markdown]
# **Give Column Name**

# %%
data_revised=pd.read_csv('/content/gdrive/MyDrive/DA_2023_lab/SMSSpamCollection.txt',sep='\t',names=['label','message'])

# %%
data_revised.head(10)
# Out:
#   label                                            message
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...
# 5  spam  FreeMsg Hey there darling it's been 3 week's n...
# 6   ham  Even my brother is not like to speak with me. ...
# 7   ham  As per your request 'Melle Melle (Oru Minnamin...
# 8  spam  WINNER!! As a valued network customer you have...
# 9  spam  Had your mobile 11 months or more? U R entitle...

# %% [markdown]
# **Information of dataset**

# %%
data_revised.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   label    5572 non-null   object
#  1   message  5572 non-null   object
# dtypes: object(2)
# memory usage: 87.2+ KB

# %% [markdown]
# **Shape of dataset**

# %%
data_revised.shape
# Out:
# (5572, 2)

# %% [markdown]
# **Columns**

# %%
data_revised.columns
# Out:
# Index(['label', 'message'], dtype='object')

# %% [markdown]
# **See uniqueness**

# %%
print(data_revised["message"].unique())
print(type(data_revised["message"].unique()))
# Out:
# ['Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...'
#  'Ok lar... Joking wif u oni...'
#  "Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's"
#  ... 'Pity, * was in mood for that. So...any other suggestions?'
#  "The guy did some bitching but I acted like i'd be interested in buying something else next week and he gave it to us for free"
#  'Rofl. Its true to its name']
# <class 'numpy.ndarray'>

# %%
print(data_revised["label"].unique())
print(type(data_revised["label"].unique()))
# Out:
# ['ham' 'spam']
# <class 'numpy.ndarray'>

# %% [markdown]
# **Checking for existing null values**

# %%
# Checking for existing null values
data_revised.isnull().values.any()
# Out:
# False

# %% [markdown]
# **Label Count**

# %%
data_revised["label"].value_counts()
# Out:
# ham     4825
# spam     747
# Name: label, dtype: int64

# %% [markdown]
# **Replace value of lable for training prupose**

# %%
data_revised["label"] = data_revised["label"].replace(['ham'],0)
data_revised["label"] = data_revised["label"].replace(['spam'],1)

# %%
data_revised.head()
# Out:
#    label                                            message
# 0      0  Go until jurong point, crazy.. Available only ...
# 1      0                      Ok lar... Joking wif u oni...
# 2      1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      0  U dun say so early hor... U c already then say...
# 4      0  Nah I don't think he goes to usf, he lives aro...

# %% [markdown]
# **create object for message and label**

# %%
text=data_revised['message']

# %%
text.head()
# Out:
# 0    Go until jurong point, crazy.. Available only ...
# 1                        Ok lar... Joking wif u oni...
# 2    Free entry in 2 a wkly comp to win FA Cup fina...
# 3    U dun say so early hor... U c already then say...
# 4    Nah I don't think he goes to usf, he lives aro...
# Name: message, dtype: object

# %%
label=data_revised['label']

# %%
label.head()
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    0
# Name: label, dtype: int64

# %% [markdown]
# **Split dataset into train and test part**

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(text, label, shuffle=True, test_size=0.30, random_state=1)

# %%
X_train.head()
# Out:
# 4393                       what are your new years plans?
# 216     Finally the match heading towards draw as your...
# 4471    Lemme know when I can swing by and pick up, I'...
# 3889                   ok....take care.umma to you too...
# 5030    I'd like to tell you my deepest darkest fantas...
# Name: message, dtype: object

# %%
print(len(X_train))
# Out:
# 3900

# %%
X_test.head()
# Out:
# 1078                         Yep, by the pretty sculpture
# 4028        Yes, princess. Are you going to make me moan?
# 958                            Welp apparently he retired
# 4642                                              Havent.
# 4674    I forgot 2 ask ü all smth.. There's a card on ...
# Name: message, dtype: object

# %%
print(len(X_test))
# Out:
# 1672

# %%
Y_train.head()
# Out:
# 4393    0
# 216     0
# 4471    0
# 3889    0
# 5030    1
# Name: label, dtype: int64

# %%
print(len(Y_train))
# Out:
# 3900

# %%
Y_test.head()
# Out:
# 1078    0
# 4028    0
# 958     0
# 4642    0
# 4674    0
# Name: label, dtype: int64

# %%
print(len(Y_test))
# Out:
# 1672

# %% [markdown]
# **Feature Extraction from CountVectorizer**

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer(analyzer ='word',ngram_range = (1,1))
vectorizer.fit(X_train)
Xtrain = vectorizer.fit_transform(X_train)
Xtest = vectorizer.transform(X_test)

# %% [markdown]
# **Model fiting and model testing**

# %%
from sklearn.metrics import accuracy_score
from sklearn import metrics
from sklearn.svm import SVC
model_SVM = SVC()
model_SVM.fit(Xtrain, Y_train)
y_pred_SVM = model_SVM.predict(Xtest)
print("SVM")
print("Accuracy score =", accuracy_score(Y_test, y_pred_SVM))
print(metrics.classification_report(Y_test, y_pred_SVM))
# Out:
# SVM
# Accuracy score = 0.9766746411483254
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      1442
#            1       0.98      0.85      0.91       230
#
#     accuracy                           0.98      1672
#    macro avg       0.98      0.92      0.95      1672
# weighted avg       0.98      0.98      0.98      1672
